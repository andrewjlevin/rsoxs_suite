# %% [markdown]
# # 2024C1-02 SMI WAXS TReXS processing notebook

# %% [markdown]
# ## Imports

# %%
import pathlib
import os
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from PIL import Image
from tqdm.auto import tqdm 

import fabio
from smi_analysis import SMI_beamline
# Out:
# WARNING:pygix.transform:Unable to import pyFAI.ocl_azim: cannot import name 'ocl_azim' from 'pyFAI' (/nsls2/conda/envs/2024-1.0-py311-tiled-rc1/lib/python3.11/site-packages/pyFAI/__init__.py)
# ERROR:pygix.transform:Unable to import pyFAI.ocl_azim_csr: cannot import name 'ocl_azim_csr' from 'pyFAI' (/nsls2/conda/envs/2024-1.0-py311-tiled-rc1/lib/python3.11/site-packages/pyFAI/__init__.py)
# ERROR:pygix.transform:Unable to import pyFAI.ocl_azim_lut for: cannot import name 'ocl_azim_lut' from 'pyFAI' (/nsls2/conda/envs/2024-1.0-py311-tiled-rc1/lib/python3.11/site-packages/pyFAI/__init__.py)
# ERROR:pygix.transform:Unable to import pyFAI.ocl_sort for: cannot import name 'ocl_sort' from 'pyFAI' (/nsls2/conda/envs/2024-1.0-py311-tiled-rc1/lib/python3.11/site-packages/pyFAI/__init__.py)

# %% [markdown]
# ## Define paths & functions

# %% [raw]
# Raw text paths for the purpose of pasting into terminal to copy/move/zip data:
#
# Raw Paths:
# /nsls2/data/smi/legacy/results/data/2024_1/313064_Davis
#
# SMI Analysis Data Paths:
# /nsls2/data/smi/legacy/results/analysis/2024_1/313064_Davis
#
# Our proposal path:
# /nsls2/data/smi/proposals/2024-1/pass-313064
#
# Rclone copy statement to paste:
# rclone --dry-run copy -LP /nsls2/data/smi/legacy/results/data/2024_1/313064_Davis/900KW /nsls2/data/smi/proposals/2024-1/pass-313064/900KW

# %%
# sample name dict
sn = {
    'SiN-0': 'Bare_SiN',
    'SiN-1': 'PM6_10CN-CB_SiN',
    'SiN-2': 'PM6_10CN-CF_SiN',
    'SiN-3': 'PM6_CB_SiN',
    'SiN-4': 'PM6_CF_SiN',
    'SiN-7': 'PM6_p5CN-2CF-3CB_SiN',
    'SiN-8': 'PM6-Y6BO_CB_SiN',
    'SiN-9': 'PM6-Y6BO_p5CN-CB_SiN',
    'SiN-10': 'PM6-Y6_CB_SiN',
    'SiN-11': 'PM6-Y6_p5CN-CB_SiN'
}

# %%
# Define paths

propPath = pathlib.Path('/nsls2/data/smi/proposals/2024-1/pass-313064')
rawPath = propPath.joinpath('900KW')

# %% [markdown]
# ### SMI function

# %%
def waxs_SMI_numpy_loading(path, filename_sublists):
    """
    Function adapted from Guillames SMI notebooks to process raw waxs tiffs:
    
    Returns filename_wa0_list, recip_list, recip_extents, caked_list, caked_extents
    """
    
    #waxs
    geometry = 'Transmission'
    bs_kind = 'pindiode'
    incident_angle = np.deg2rad(0)

    #WAXS
    detector_waxs = 'Pilatus900kw'
    sdd_waxs = 280
    center_waxs = [97, 1255.9]
    bs_pos_waxs = [[97, 1070], [0, 0], [0, 0]]
    
    flatPath = pathlib.Path('/nsls2/data/smi/legacy/results/analysis/2024_1/314483_Freychet_04')
    flatfield = np.rot90(fabio.open(flatPath.joinpath('GF_Flatfield_Sedge_uhighg1600eV_10s_wa20_2477eV_pffBT4T_id481136_000000_WAXS.tif')).data, 1)

    
    filename_wa0_list = []
    recip_list = []
    recip_extents = []
    caked_list = []
    caked_extents = []
    for dat in tqdm(filename_sublists, desc='Processing tiffs'):
        
            waxs_angle = [np.deg2rad(-0.06), np.deg2rad(19.7-0.06)]
            # print(dat)

            idx = dat[0].find('eV')
            energy = 0.001*float(dat[0][idx-7:idx])
            # print(energy)
            wav = 1E-10 * (12.398/energy)

            #This part is to stitch the data
            SMI_waxs = SMI_beamline.SMI_geometry(geometry = geometry,
                                                 detector = detector_waxs,
                                                 sdd = sdd_waxs,
                                                 wav = wav,
                                                 alphai = 0,
                                                 center = center_waxs,
                                                 bs_pos = bs_pos_waxs,
                                                 det_angles = waxs_angle,
                                                 bs_kind = None)


            SMI_waxs.open_data(path, dat)
            
            SMI_waxs.masks[1][1254, 47], SMI_waxs.masks[1][1255, 47]=True, True
            SMI_waxs.masks[4][1254, 47], SMI_waxs.masks[4][1255, 47]=True, True

            SMI_waxs.masks[1][979:1050, 0:100], SMI_waxs.masks[4][979:1050, 0:100]=True, True
            SMI_waxs.masks[1][967, 67], SMI_waxs.masks[4][967, 67]=True, True

            SMI_waxs.masks[1][490:555, 100:], SMI_waxs.masks[4][490:555, 100:]=True, True

            SMI_waxs.masks[1][1231, 174], SMI_waxs.masks[1][1232, 174]=True, True
            SMI_waxs.masks[4][1231, 174], SMI_waxs.masks[4][1232, 174]=True, True

            SMI_waxs.masks[1][1414, 179], SMI_waxs.masks[1][1415, 179]=True, True
            SMI_waxs.masks[4][1414, 179], SMI_waxs.masks[4][1415, 179]=True, True

            SMI_waxs.masks[1][858, 5], SMI_waxs.masks[1][859, 5]=True, True
            SMI_waxs.masks[4][858, 5], SMI_waxs.masks[4][859, 5]=True, True

            SMI_waxs.masks[1][414, 6], SMI_waxs.masks[4][414, 6], =True, True
            SMI_waxs.masks[1][394, 138], SMI_waxs.masks[4][394, 138]=True, True

            SMI_waxs.masks[1][364, 41], SMI_waxs.masks[1][365, 41]=True, True
            SMI_waxs.masks[4][364, 41], SMI_waxs.masks[4][365, 41]=True, True

            SMI_waxs.masks[1][364, 96], SMI_waxs.masks[1][365, 96]=True, True
            SMI_waxs.masks[4][364, 96], SMI_waxs.masks[4][365, 96]=True, True

            SMI_waxs.masks[1][304, 96], SMI_waxs.masks[1][305, 96], SMI_waxs.masks[1][304, 97], SMI_waxs.masks[1][305, 97]=True, True, True, True
            SMI_waxs.masks[4][304, 96], SMI_waxs.masks[4][305, 96], SMI_waxs.masks[4][304, 97], SMI_waxs.masks[4][305, 97]=True, True, True, True

            SMI_waxs.masks[1][181, 97], SMI_waxs.masks[1][182, 97], SMI_waxs.masks[1][181, 98], SMI_waxs.masks[1][182, 98]=True, True, True, True
            SMI_waxs.masks[4][181, 97], SMI_waxs.masks[4][182, 97], SMI_waxs.masks[4][181, 98], SMI_waxs.masks[4][182, 98]=True, True, True, True

            for i, (img, mask) in enumerate(zip(SMI_waxs.imgs, SMI_waxs.masks)):
                if i%3==0:
                    SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, :195]+1E-7
                    SMI_waxs.masks[i][np.where(flatfield[:, :195]<1)] = True

                if i%3==1:
                    SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
                    SMI_waxs.masks[i][np.where(flatfield[:, 211:406]<1)] = True

                if i%3==2:
                    SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, -195:]+1E-7
                    SMI_waxs.masks[i][np.where(flatfield[:, -195:]<1)] = True

            SMI_waxs.stitching_data(interp_factor=3, flag_scale=False)
            
            SMI_waxs.caking()
            
            filename_wa0_list.append(dat[0])
            recip_list.append(SMI_waxs.img_st)
            recip_extents.append([SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]])
            
            caked_list.append(SMI_waxs.cake)
            caked_extents.append([SMI_waxs.q_cake[0], SMI_waxs.q_cake[-1], SMI_waxs.chi_cake[0], SMI_waxs.chi_cake[-1]])
            
    return filename_wa0_list, recip_list, recip_extents, caked_list, caked_extents

# %% [markdown]
# ## Load data & save zarrs

# %%
filenames = [f.name for f in rawPath.glob('TC_SiN-3*')]
f = filenames[0]
# f.split('_')
float(f[f.find('_id')+1:].split('_')[0][2:])
# Out:
# 599762.0

# %%
def get_id(f):
    return float(f[f.find('_id')+1:].split('_')[0][2:])

# sorted(filenames, key=lambda x: float(x[x.find('_id')+1:].split('_')[0][2:]))
sorted(filenames, key=lambda x: get_id(x))
# Out:
# ['TC_SiN-3_prs0deg_sdd1.8m_2445.00eV_wa0_bpm1.462_id598958_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2450.00eV_wa0_bpm1.497_id598959_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2455.00eV_wa0_bpm1.522_id598960_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2460.00eV_wa0_bpm1.541_id598961_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2465.00eV_wa0_bpm1.570_id598962_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2470.00eV_wa0_bpm1.601_id598963_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2472.00eV_wa0_bpm1.600_id598964_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2473.00eV_wa0_bpm1.593_id598965_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2474.00eV_wa0_bpm1.620_id598966_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2474.50eV_wa0_bpm1.601_id598967_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2475.00eV_wa0_bpm1.609_id598968_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2475.50eV_wa0_bpm1.615_id598969_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2476.00eV_wa0_bpm1.611_id598970_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2476.50eV_wa0_bpm1.613_id598971_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2477.00eV_wa0_bpm1.608_id598972_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2477.50eV_wa0_bpm1.613_id598973_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2478.00eV_wa0_bpm1.614_id598974_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2478.50eV_wa0_bpm1.610_id598975_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2479.00eV_wa0_bpm1.609_id598976_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2479.50eV_wa0_bpm1.613_id598977_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2480.00eV_wa0_bpm1.640_id598978_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2480.50eV_wa0_bpm1.616_id598979_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2481.00eV_wa0_bpm1.629_id598980_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2482.00eV_wa0_bpm1.631_id598981_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2483.00eV_wa0_bpm1.623_id598982_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2484.00eV_wa0_bpm1.645_id598983_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2485.00eV_wa0_bpm1.638_id598984_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2486.00eV_wa0_bpm1.665_id598985_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2487.00eV_wa0_bpm1.658_id598986_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2488.00eV_wa0_bpm1.678_id598987_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2489.00eV_wa0_bpm1.672_id598988_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2490.00eV_wa0_bpm1.689_id598989_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2492.50eV_wa0_bpm1.702_id598990_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2495.00eV_wa0_bpm1.725_id598991_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2500.00eV_wa0_bpm1.743_id598992_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2510.00eV_wa0_bpm1.815_id598993_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2515.00eV_wa0_bpm1.845_id598994_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2530.00eV_wa0_bpm1.946_id598995_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2550.00eV_wa0_bpm2.058_id598996_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2445.00eV_wa20_bpm1.472_id598997_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2450.00eV_wa20_bpm1.485_id598998_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2455.00eV_wa20_bpm1.507_id598999_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2460.00eV_wa20_bpm1.538_id599000_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2465.00eV_wa20_bpm1.553_id599001_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2470.00eV_wa20_bpm1.586_id599002_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2472.00eV_wa20_bpm1.589_id599003_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2473.00eV_wa20_bpm1.593_id599004_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2474.00eV_wa20_bpm1.599_id599005_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2474.50eV_wa20_bpm1.606_id599006_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2475.00eV_wa20_bpm1.592_id599007_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2475.50eV_wa20_bpm1.596_id599008_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2476.00eV_wa20_bpm1.603_id599009_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2476.50eV_wa20_bpm1.598_id599010_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2477.00eV_wa20_bpm1.610_id599011_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2477.50eV_wa20_bpm1.609_id599012_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2478.00eV_wa20_bpm1.613_id599013_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2478.50eV_wa20_bpm1.623_id599014_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2479.00eV_wa20_bpm1.611_id599015_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2479.50eV_wa20_bpm1.623_id599016_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2480.00eV_wa20_bpm1.619_id599017_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2480.50eV_wa20_bpm1.631_id599018_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2481.00eV_wa20_bpm1.652_id599019_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2482.00eV_wa20_bpm1.644_id599020_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2483.00eV_wa20_bpm1.649_id599021_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2484.00eV_wa20_bpm1.652_id599022_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2485.00eV_wa20_bpm1.658_id599023_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2486.00eV_wa20_bpm1.657_id599024_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2487.00eV_wa20_bpm1.674_id599025_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2488.00eV_wa20_bpm1.677_id599026_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2489.00eV_wa20_bpm1.687_id599027_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2490.00eV_wa20_bpm1.691_id599028_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2492.50eV_wa20_bpm1.707_id599029_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2495.00eV_wa20_bpm1.723_id599030_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2500.00eV_wa20_bpm1.744_id599031_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2510.00eV_wa20_bpm1.804_id599032_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2515.00eV_wa20_bpm1.853_id599033_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2530.00eV_wa20_bpm1.965_id599034_000000_WAXS.tif',
#  'TC_SiN-3_prs0deg_sdd1.8m_2550.00eV_wa20_bpm2.072_id599035_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2445.00eV_wa0_bpm1.472_id599738_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2450.00eV_wa0_bpm1.483_id599739_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2455.00eV_wa0_bpm1.522_id599740_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2460.00eV_wa0_bpm1.536_id599741_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2465.00eV_wa0_bpm1.561_id599742_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2470.00eV_wa0_bpm1.587_id599743_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2472.00eV_wa0_bpm1.593_id599744_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2473.00eV_wa0_bpm1.586_id599745_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.00eV_wa0_bpm1.597_id599746_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.50eV_wa0_bpm1.618_id599747_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.00eV_wa0_bpm1.613_id599748_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.50eV_wa0_bpm1.605_id599749_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.00eV_wa0_bpm1.615_id599750_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.50eV_wa0_bpm1.615_id599751_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.00eV_wa0_bpm1.615_id599752_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.50eV_wa0_bpm1.614_id599753_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.00eV_wa0_bpm1.611_id599754_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.50eV_wa0_bpm1.613_id599755_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.00eV_wa0_bpm1.626_id599756_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.50eV_wa0_bpm1.620_id599757_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.00eV_wa0_bpm1.643_id599758_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.50eV_wa0_bpm1.640_id599759_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2481.00eV_wa0_bpm1.635_id599760_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2482.00eV_wa0_bpm1.633_id599761_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2483.00eV_wa0_bpm1.650_id599762_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2484.00eV_wa0_bpm1.646_id599763_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2485.00eV_wa0_bpm1.640_id599764_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2486.00eV_wa0_bpm1.667_id599765_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2487.00eV_wa0_bpm1.665_id599766_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2488.00eV_wa0_bpm1.672_id599767_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2489.00eV_wa0_bpm1.685_id599768_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2490.00eV_wa0_bpm1.690_id599769_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2492.50eV_wa0_bpm1.716_id599770_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2495.00eV_wa0_bpm1.726_id599771_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2500.00eV_wa0_bpm1.751_id599772_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2510.00eV_wa0_bpm1.811_id599773_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2515.00eV_wa0_bpm1.858_id599774_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2530.00eV_wa0_bpm1.947_id599775_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2550.00eV_wa0_bpm2.048_id599776_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2445.00eV_wa20_bpm1.481_id599777_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2450.00eV_wa20_bpm1.485_id599778_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2455.00eV_wa20_bpm1.519_id599779_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2460.00eV_wa20_bpm1.549_id599780_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2465.00eV_wa20_bpm1.568_id599781_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2470.00eV_wa20_bpm1.598_id599782_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2472.00eV_wa20_bpm1.609_id599783_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2473.00eV_wa20_bpm1.609_id599784_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.00eV_wa20_bpm1.614_id599785_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.50eV_wa20_bpm1.622_id599786_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.00eV_wa20_bpm1.614_id599787_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.50eV_wa20_bpm1.619_id599788_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.00eV_wa20_bpm1.608_id599789_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.50eV_wa20_bpm1.602_id599790_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.00eV_wa20_bpm1.620_id599791_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.50eV_wa20_bpm1.632_id599792_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.00eV_wa20_bpm1.625_id599793_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.50eV_wa20_bpm1.627_id599794_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.00eV_wa20_bpm1.639_id599795_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.50eV_wa20_bpm1.636_id599796_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.00eV_wa20_bpm1.639_id599797_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.50eV_wa20_bpm1.634_id599798_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2481.00eV_wa20_bpm1.633_id599799_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2482.00eV_wa20_bpm1.636_id599800_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2483.00eV_wa20_bpm1.647_id599801_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2484.00eV_wa20_bpm1.644_id599802_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2485.00eV_wa20_bpm1.660_id599803_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2486.00eV_wa20_bpm1.659_id599804_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2487.00eV_wa20_bpm1.674_id599805_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2488.00eV_wa20_bpm1.675_id599806_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2489.00eV_wa20_bpm1.681_id599807_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2490.00eV_wa20_bpm1.683_id599808_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2492.50eV_wa20_bpm1.708_id599809_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2495.00eV_wa20_bpm1.712_id599810_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2500.00eV_wa20_bpm1.756_id599811_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2510.00eV_wa20_bpm1.805_id599812_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2515.00eV_wa20_bpm1.834_id599813_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2530.00eV_wa20_bpm1.931_id599814_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2550.00eV_wa20_bpm2.054_id599815_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2445.00eV_wa0_bpm1.489_id600518_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2450.00eV_wa0_bpm1.523_id600519_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2455.00eV_wa0_bpm1.539_id600520_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2460.00eV_wa0_bpm1.572_id600521_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2465.00eV_wa0_bpm1.592_id600522_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2470.00eV_wa0_bpm1.595_id600523_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2472.00eV_wa0_bpm1.607_id600524_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2473.00eV_wa0_bpm1.603_id600525_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2474.00eV_wa0_bpm1.618_id600526_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2474.50eV_wa0_bpm1.632_id600527_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2475.00eV_wa0_bpm1.637_id600528_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2475.50eV_wa0_bpm1.640_id600529_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2476.00eV_wa0_bpm1.644_id600530_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2476.50eV_wa0_bpm1.647_id600531_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2477.00eV_wa0_bpm1.646_id600532_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2477.50eV_wa0_bpm1.655_id600533_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2478.00eV_wa0_bpm1.667_id600534_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2478.50eV_wa0_bpm1.672_id600535_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2479.00eV_wa0_bpm1.672_id600536_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2479.50eV_wa0_bpm1.673_id600537_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2480.00eV_wa0_bpm1.677_id600538_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2480.50eV_wa0_bpm1.672_id600539_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2481.00eV_wa0_bpm1.672_id600540_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2482.00eV_wa0_bpm1.665_id600541_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2483.00eV_wa0_bpm1.671_id600542_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2484.00eV_wa0_bpm1.696_id600543_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2485.00eV_wa0_bpm1.684_id600544_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2486.00eV_wa0_bpm1.685_id600545_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2487.00eV_wa0_bpm1.701_id600546_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2488.00eV_wa0_bpm1.715_id600547_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2489.00eV_wa0_bpm1.710_id600548_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2490.00eV_wa0_bpm1.719_id600549_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2492.50eV_wa0_bpm1.740_id600550_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2495.00eV_wa0_bpm1.762_id600551_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2500.00eV_wa0_bpm1.775_id600552_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2510.00eV_wa0_bpm1.836_id600553_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2515.00eV_wa0_bpm1.872_id600554_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2530.00eV_wa0_bpm1.999_id600555_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2550.00eV_wa0_bpm2.105_id600556_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2445.00eV_wa20_bpm1.521_id600557_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2450.00eV_wa20_bpm1.533_id600558_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2455.00eV_wa20_bpm1.560_id600559_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2460.00eV_wa20_bpm1.575_id600560_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2465.00eV_wa20_bpm1.593_id600561_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2470.00eV_wa20_bpm1.630_id600562_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2472.00eV_wa20_bpm1.641_id600563_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2473.00eV_wa20_bpm1.652_id600564_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2474.00eV_wa20_bpm1.658_id600565_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2474.50eV_wa20_bpm1.676_id600566_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2475.00eV_wa20_bpm1.666_id600567_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2475.50eV_wa20_bpm1.657_id600568_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2476.00eV_wa20_bpm1.666_id600569_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2476.50eV_wa20_bpm1.667_id600570_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2477.00eV_wa20_bpm1.673_id600571_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2477.50eV_wa20_bpm1.674_id600572_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2478.00eV_wa20_bpm1.665_id600573_000000_WAXS.tif',
#  'TC_SiN-3_prs55deg_sdd1.8m_2478.50eV_wa20_bpm1.669_id600574_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2445.00eV_wa0_bpm1.458_id604562_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2450.00eV_wa0_bpm1.456_id604563_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2455.00eV_wa0_bpm1.496_id604564_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2460.00eV_wa0_bpm1.500_id604565_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2465.00eV_wa0_bpm1.539_id604566_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2470.00eV_wa0_bpm1.575_id604567_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2472.00eV_wa0_bpm1.574_id604568_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2473.00eV_wa0_bpm1.572_id604569_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.00eV_wa0_bpm1.575_id604570_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.50eV_wa0_bpm1.571_id604571_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.00eV_wa0_bpm1.564_id604572_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.50eV_wa0_bpm1.581_id604573_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.00eV_wa0_bpm1.577_id604574_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.50eV_wa0_bpm1.573_id604575_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.00eV_wa0_bpm1.588_id604576_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.50eV_wa0_bpm1.575_id604577_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.00eV_wa0_bpm1.579_id604578_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.50eV_wa0_bpm1.595_id604579_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.00eV_wa0_bpm1.596_id604580_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.50eV_wa0_bpm1.596_id604581_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.00eV_wa0_bpm1.595_id604582_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.50eV_wa0_bpm1.586_id604583_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2481.00eV_wa0_bpm1.596_id604584_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2482.00eV_wa0_bpm1.590_id604585_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2483.00eV_wa0_bpm1.603_id604586_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2484.00eV_wa0_bpm1.615_id604587_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2485.00eV_wa0_bpm1.617_id604588_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2486.00eV_wa0_bpm1.630_id604589_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2487.00eV_wa0_bpm1.629_id604590_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2488.00eV_wa0_bpm1.642_id604591_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2489.00eV_wa0_bpm1.641_id604592_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2490.00eV_wa0_bpm1.625_id604593_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2492.50eV_wa0_bpm1.650_id604594_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2495.00eV_wa0_bpm1.690_id604595_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2500.00eV_wa0_bpm1.713_id604596_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2510.00eV_wa0_bpm1.781_id604597_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2515.00eV_wa0_bpm1.821_id604598_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2530.00eV_wa0_bpm1.914_id604599_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2550.00eV_wa0_bpm2.005_id604600_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2445.00eV_wa20_bpm1.436_id604601_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2450.00eV_wa20_bpm1.451_id604602_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2455.00eV_wa20_bpm1.483_id604603_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2460.00eV_wa20_bpm1.492_id604604_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2465.00eV_wa20_bpm1.520_id604605_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2470.00eV_wa20_bpm1.543_id604606_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2472.00eV_wa20_bpm1.542_id604607_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2473.00eV_wa20_bpm1.563_id604608_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.00eV_wa20_bpm1.570_id604609_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2474.50eV_wa20_bpm1.574_id604610_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.00eV_wa20_bpm1.569_id604611_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2475.50eV_wa20_bpm1.586_id604612_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.00eV_wa20_bpm1.562_id604613_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2476.50eV_wa20_bpm1.563_id604614_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.00eV_wa20_bpm1.576_id604615_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2477.50eV_wa20_bpm1.572_id604616_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.00eV_wa20_bpm1.573_id604617_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2478.50eV_wa20_bpm1.590_id604618_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.00eV_wa20_bpm1.578_id604619_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2479.50eV_wa20_bpm1.581_id604620_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.00eV_wa20_bpm1.594_id604621_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2480.50eV_wa20_bpm1.580_id604622_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2481.00eV_wa20_bpm1.578_id604623_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2482.00eV_wa20_bpm1.585_id604624_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2483.00eV_wa20_bpm1.594_id604625_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2484.00eV_wa20_bpm1.618_id604626_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2485.00eV_wa20_bpm1.608_id604627_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2486.00eV_wa20_bpm1.639_id604628_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2487.00eV_wa20_bpm1.642_id604629_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2488.00eV_wa20_bpm1.654_id604630_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2489.00eV_wa20_bpm1.660_id604631_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2490.00eV_wa20_bpm1.673_id604632_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2492.50eV_wa20_bpm1.681_id604633_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2495.00eV_wa20_bpm1.673_id604634_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2500.00eV_wa20_bpm1.702_id604635_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2510.00eV_wa20_bpm1.768_id604636_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2515.00eV_wa20_bpm1.814_id604637_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2530.00eV_wa20_bpm1.908_id604638_000000_WAXS.tif',
#  'TC_SiN-3_prs35deg_sdd1.8m_2550.00eV_wa20_bpm2.028_id604639_000000_WAXS.tif']

# %%
# all_saxs = set(waxsPath1.glob('*.tif'))
# test_saxs = set(waxsPath1.glob('test*'))
# sample_names = sorted(set([f.name[3:f.name.find('_sdd1.8')] for f in all_saxs.difference(test_saxs)]))[:-1]
# sample_names

# %%
unique_sample_numbers = sorted(set([f.name.split('_')[1] for f in rawPath.glob('TC*')]), key=lambda x: float(x.split('-')[-1]))
unique_sample_rotations = sorted(set([f.name.split('_')[2] for f in rawPath.glob('TC*')]))

# %%
# filename_list = [f.name for f in sorted(waxsPath.glob('*Trmsn_18*prs35*'))]

# # Make sublists (of sample filenames)
# group_size = 2
# filename_sublists = [filename_list[i:i + group_size] for i in range(0, len(filename_list), group_size)]

# %%
# filename_sublists

# %%
# import warnings
# warnings.filterwarnings('ignore')

# %%
def remove_duplicate_energies(filename_list):
    file_energies = []
    kept_files = []

    for filename in filename_list:
        file_energy = filename[:filename.find('eV')].split('_')[-1]
        if file_energy in file_energies:
            pass
        else:
            file_energies.append(file_energy)
            kept_files.append(filename)

    return kept_files

# %%
for sample_number in unique_sample_numbers[1:2]:
    all_paths = set(rawPath.glob(f'TC*_{sample_number}_*prs0deg*'))
    display([f.name for f in sorted(all_paths, key=lambda x: x.stem.split('_')[7])])
    print(len([f.name for f in sorted(all_paths, key=lambda x: x.stem.split('_')[7])]))

# %%
# 598792
for sample_number in unique_sample_numbers[1:2]:
    all_paths = set(rawPath.glob(f'TC*_{sample_number}_*prs0deg*'))
    all_paths = [f.name for f in sorted(all_paths, key=lambda x: x.stem.split('_')[7]) 
                 if float(f.stem.split('_')[7][2:]) > 598792]
    print(len(all_paths))
    display(all_paths)

# %%
# We need to check that the number of energies for the 2 detector positions is consistent (63)
wa0_filename_list = [fname for fname in filenames if 'wa0' in fname]
wa20_filename_list = [fname for fname in filenames if 'wa20' in fname]
if len(wa0_filename_list) == num_energies:
    pass
else:
    wa0_filename_list = remove_duplicate_energies(wa0_filename_list)

if len(wa20_filename_list) == num_energies:
    pass
else:
    wa20_filename_list = remove_duplicate_energies(wa20_filename_list)

# %%
len(wa0_filename_list)

# %%
len(wa20_filename_list)

# %%
filename_list = sorted(wa0_filename_list + wa20_filename_list)
# len(filename_list)
# Make sublists to stitch two waxs positions together
group_size = 2
filename_sublists = [filename_list[i:i + group_size] for i in range(0, len(filename_list), group_size)]

# %%
len(filename_sublists)

# %%
all_paths

# %%
unique_sample_rotations

# %%
all_paths

# %%
# Cell for scans with incident angle recorded in name

num_energies = 39

for sample_number in tqdm(unique_sample_numbers[1:], desc='Samples'):
    for sample_rotation in tqdm(unique_sample_rotations[1:2], desc='Angles'):

        # Select files for a given sample and rotation
        all_paths = set(rawPath.glob(f'TC*_{sample_number}_*{sample_rotation}_*'))
        
        # For now only select first scans, not the damage test repeats
        # filename_list = [f.name for f in sorted(all_paths)]
        filename_list = [f.name for f in sorted(all_paths, key=lambda x: x.stem.split('_')[7]) 
                         if float(f.stem.split('_')[7][2:]) > 598792]
        
        # We need to check that the number of energies for the 2 detector positions is consistent (63)
        wa0_filename_list = [fname for fname in filename_list if 'wa0' in fname]
        wa20_filename_list = [fname for fname in filename_list if 'wa20' in fname]
        if len(wa0_filename_list) == num_energies:
            pass
        else:
            wa0_filename_list = remove_duplicate_energies(wa0_filename_list)

        if len(wa20_filename_list) == num_energies:
            pass
        else:
            wa20_filename_list = remove_duplicate_energies(wa20_filename_list)
            
        filename_list =  sorted(wa0_filename_list + wa20_filename_list)
        
        # Make sublists to stitch two waxs positions together
        group_size = 2
        filename_sublists = [filename_list[i:i + group_size] for i in range(0, len(filename_list), group_size)]

        # Run SMI loading code (this produces some fabio and divide by zero errors)
        names_list, recip_list, recip_extents, caked_list, caked_extents = waxs_SMI_numpy_loading(rawPath, filename_sublists)

        

        # Define naming scheme:
        waxs_naming_scheme = ['project', 'sample_number', 'rotation_from_normal', 'set_sdd', 'energy', 'waxs_det_position',
                              'bpm', 'id', 'misc', 'detector']
        md_naming_scheme = waxs_naming_scheme.copy()


        # Construct xarrays with full values along detector dimensions and the energy dimension
        # They contain sample name and theta value as well, as single values to be concatenated in later steps
        recip_DA_rows = []
        caked_DA_rows = []
        zipped_lists = zip(names_list, recip_list, recip_extents, caked_list, caked_extents)
        for filename, recip_arr, recip_extent, caked_arr, caked_extent in zipped_lists:
            # print(filename)
            # print(recip_arr.shape)
            # print(recip_extent)
            # print(caked_arr.shape)
            # print(caked_extent)

            attr_dict = {}
            md_list = filename.split('_')
            for i, md_item in enumerate(md_naming_scheme):
                attr_dict[md_item] = md_list[i]

            recip_DA = xr.DataArray(data = recip_arr, 
                                    dims = ['pix_y', 'pix_x'],
                                    attrs = attr_dict)
            recip_DA = recip_DA.assign_coords({
                'pix_x': recip_DA.pix_x.data,
                'pix_y': recip_DA.pix_y.data,
                'q_x': ('pix_x', np.linspace(recip_extent[0], recip_extent[1], len(recip_DA.pix_x.data))),
                'q_y': ('pix_y', np.linspace(recip_extent[3], recip_extent[2], len(recip_DA.pix_y.data)))
            })
            recip_DA = recip_DA.expand_dims({
                'energy': [float(recip_DA.energy[:-2])],
                'sample_name': [sn[recip_DA.sample_number]],
                'theta': [90 - float(recip_DA.rotation_from_normal[3:-3])]
            })
            recip_DA_rows.append(recip_DA)

            caked_DA = xr.DataArray(data = caked_arr, 
                                    dims = ['index_y', 'index_x'],
                                    attrs = attr_dict)
            caked_DA = caked_DA.assign_coords({
                'index_x': caked_DA.index_x.data,
                'index_y': caked_DA.index_y.data,
                'q_r': ('index_x', np.linspace(caked_extent[0], caked_extent[1], len(caked_DA.index_x.data))),
                'chi': ('index_y', np.linspace(caked_extent[3], caked_extent[2], len(caked_DA.index_y.data)))
            }) 
            caked_DA = caked_DA.expand_dims({
                'energy': [float(caked_DA.energy[:-2])],
                'sample_name': [sn[caked_DA.sample_number]],
                'theta': [90 - float(caked_DA.rotation_from_normal[3:-3])]
            })
            caked_DA_rows.append(caked_DA)

        recip_DA = xr.concat(recip_DA_rows, 'energy')
        caked_DA = xr.concat(caked_DA_rows, 'energy')

        # Save sample zarr, load later to concatenate full zarr
        sampleZarrsPath = propPath.joinpath('processed_data/andrew/zarrs')

        recip_samp_zarr_name = 'recip_'+recip_DA.sample_name.values[0]+'_'+str(int(recip_DA.theta.values[0]))+'deg.zarr'
        recip_DS = recip_DA.to_dataset(name='flatfield_corr')
        recip_DS.to_zarr(sampleZarrsPath.joinpath(recip_samp_zarr_name), mode='w')

        caked_samp_zarr_name = 'caked_'+caked_DA.sample_name.values[0]+'_'+str(int(caked_DA.theta.values[0]))+'deg.zarr'
        caked_DS = caked_DA.to_dataset(name='flatfield_corr')
        caked_DS.to_zarr(sampleZarrsPath.joinpath(caked_samp_zarr_name), mode='w')
# Out:
# Samples:   0%|          | 0/9 [00:00<?, ?it/s]
# Angles:   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# Processing tiffs:   0%|          | 0/39 [00:00<?, ?it/s]
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# /tmp/ipykernel_31811/1338544897.py:86: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, :195]+1E-7
# /tmp/ipykernel_31811/1338544897.py:90: RuntimeWarning: divide by zero encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
# /tmp/ipykernel_31811/1338544897.py:90: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
# /tmp/ipykernel_31811/1338544897.py:94: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, -195:]+1E-7
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# /tmp/ipykernel_31811/1338544897.py:86: RuntimeWarning: divide by zero encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, :195]+1E-7
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# Angles:   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# Processing tiffs:   0%|          | 0/39 [00:00<?, ?it/s]
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# /tmp/ipykernel_31811/1338544897.py:86: RuntimeWarning: divide by zero encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, :195]+1E-7
# /tmp/ipykernel_31811/1338544897.py:86: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, :195]+1E-7
# /tmp/ipykernel_31811/1338544897.py:90: RuntimeWarning: divide by zero encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
# /tmp/ipykernel_31811/1338544897.py:90: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
# /tmp/ipykernel_31811/1338544897.py:94: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, -195:]+1E-7
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# Angles:   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# Processing tiffs:   0%|          | 0/39 [00:00<?, ?it/s]
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# /tmp/ipykernel_31811/1338544897.py:86: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, :195]+1E-7
# /tmp/ipykernel_31811/1338544897.py:90: RuntimeWarning: divide by zero encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
# /tmp/ipykernel_31811/1338544897.py:90: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
# /tmp/ipykernel_31811/1338544897.py:94: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, -195:]+1E-7
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# /tmp/ipykernel_31811/1338544897.py:86: RuntimeWarning: divide by zero encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, :195]+1E-7
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# ...
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, 211:406]+1E-7
# /tmp/ipykernel_31811/1338544897.py:94: RuntimeWarning: invalid value encountered in divide
#   SMI_waxs.imgs[i] = SMI_waxs.imgs[i]/flatfield[:, -195:]+1E-7
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected
# WARNING:fabio.TiffIO:Data at tag id '65000' is smaller than expected

# %%
caked_DA = xr.open_zarr(sampleZarrsPath.joinpath('caked_PM6_5CN-CB_55deg.zarr'))['flatfield_corr']
caked_DA

# %%
recip_DA.sel(energy=1e10,method='nearest').plot.imshow(vmin=0,vmax=np.percentile(SMI_waxs.img_st, 99), x='q_x', y='q_y')
plt.show()

# %%
caked_DA.squeeze().sel(energy=0,method='nearest').plot.imshow(vmin=0,vmax=np.percentile(SMI_waxs.cake, 97), x='q_r', y='chi')
plt.show()

# %%
# trmsn_35_tot = sorted(reducedPath.glob('*tot*Trmsn_35*.txt'))
# trmsn_35_ver = sorted(reducedPath.glob('*ver*Trmsn_35*.txt'))
# trmsn_35_hor = sorted(reducedPath.glob('*hor*Trmsn_35*.txt'))

# len([f.name for f in trmsn_35_tot])

# %%
# for file in trmsn_35_tot:
#     pr = np.loadtxt(file)
#     plt.plot(pr[:, 1]-0.9*np.mean(pr[1100:1250, 1]))
#     plt.show()
#     plt.close()
