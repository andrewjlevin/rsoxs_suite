# %% [markdown]
# # Example notebook for loading nanosurf AFM data through the NSFopen package:

# %%
# !pip install NSFopen  # Must run this once per session & restart kernel afterwards

# %%
# Imports
import pathlib
import numpy as np
import matplotlib.pyplot as plt
# from matplotlib.colors import LogNorm
from NSFopen.read import read as afmreader

# %%
# Copied example functions for plane fitting & median search:

def fit2DPlane(matrix, xaxis, yaxis):
    m = len(xaxis)
    X1, Y1 = np.meshgrid(xaxis, yaxis)
    X = np.hstack(( np.reshape(X1, (m*m, 1)) , np.reshape(Y1, (m*m, 1)) ))
    X = np.hstack(( np.ones((m*m, 1)) , X ))
    YY = np.reshape(matrix, (m*m, 1))

    theta = np.dot(np.dot( np.linalg.pinv(np.dot(X.transpose(), X)), X.transpose()), YY)
    plane = np.reshape(np.dot(X, theta), (m, m))
    
    return plane

def findLimits(matrix, strength):
    array1D = matrix.flatten()
    mean = np.mean(array1D)
    stdev = np.std(array1D)
    armin = mean - strength/2*stdev
    armax = mean + strength/2*stdev
    return armin, armax

# %%
# Define paths

rootPath = pathlib.Path('/nsls2/users/alevin/rsoxs_suite')
afmsPath = rootPath.joinpath('afm_data/SST1_2023C2')
dataPath = afmsPath.joinpath('2023-07-24')

# %%
afms_list = sorted(dataPath.glob('*'))
afms_list
# Out:
# [PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlO-test.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp1_00823.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp1_00824.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp1_00825.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp1_00826.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp2_00827.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp2_00828.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp2_00829.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp2_00830.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp2_00831.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_AlOp2_00832.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_PM6-Y6p1_00841.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_PM6-Y6p1_00842.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_PM6-Y6p1_00843.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_PM6p1_00838.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_PM6p1_00839.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_PM6p1_00840.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_Y6p1_00833.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_Y6p1_00834.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_Y6p1_00835.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_Y6p1_00836.nid'),
#  PosixPath('/nsls2/users/alevin/rsoxs_suite/afm_data/SST1_2023C2/2023-07-24/levin_Y6p1_00837.nid')]

# %%
afm_obj = afmreader(sorted(dataPath.glob('*840*'))[0])

# %%
data = afm_obj.data['Image']['Forward']['Z-Axis']
param = afm_obj.param
data.shape
# Out:
# (512, 512)

# %%
xrange = param['X']['range'][0]*1e9  # Convert m to nm
yrange = param['Y']['range'][0]*1e9  # Convert m to nm
print(f'({xrange}, {yrange})')

xaxis = np.linspace(0, xrange, len(data[0]))
yaxis = np.linspace(0, yrange, len(data[1]))
# Out:
# (700.0, 700.0)

# %%
plane = fit2DPlane(data, xaxis, yaxis)
data_levelled = data - plane

# %%
#Plot 
cmin = np.percentile(data_levelled, 1)
cmax = np.percentile(data_levelled, 99)

fig, axs = plt.subplots(1,3)
fig.set(tight_layout=True, size_inches=(12, 4), dpi=120)
axs[0].imshow(data, origin='lower', extent=[0, xrange, 0, yrange])
axs[0].set_title('Raw AFM Data')
axs[1].imshow(plane, origin='lower', extent=[0, xrange, 0, yrange])
axs[1].set_title('Fitted 2D Plane')
axs[2].imshow(data_levelled, origin='lower', extent=[0, xrange, 0, yrange], vmin=cmin, vmax=cmax)
axs[2].set_title('Levelled AFM Data')

for ax in axs:
    ax.set(xlabel='X [nm]', ylabel='Y [nm]')

sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=plt.Normalize(cmin, cmax))
cax = axs[2].inset_axes([1.1, 0, 0.05, 1])
fig.colorbar(sm, cax=cax)

plt.show()
